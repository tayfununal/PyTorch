# %% [markdown]
# <a href="https://colab.research.google.com/github/tayfununal/PyTorch/blob/main/normal_dist_calisma_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: 2 dim normal distribution by pytorch distribution library and plot

import torch
import torch.distributions as dist
import matplotlib.pyplot as plt

# define parameters of the distribution
mu = torch.tensor([0., 0.])
sigma = torch.tensor([[1., 0.], [0., 1.]])

# create a multivariate normal distribution
mvn = dist.MultivariateNormal(mu, sigma)

# sample from the distribution
x = mvn.sample((1000,))

# plot the samples
plt.scatter(x[:, 0], x[:, 1])
plt.show()

# %%
# sample from the distribution
x = mvn.sample((1000,))
t_1 = 2*x+5

# plot the samples
plt.scatter(t_1[:, 0], t_1[:, 1])
plt.show()

# %%
torch.var(t_1)
# Out:
# tensor(4.0751)

# %%
norm = dist.normal.Normal(torch.tensor([0.]), torch.tensor([1.]))
norm_sample = norm.sample((1000,))
a = torch.tensor([i for i in torch.linspace(-5,5,100)])

# %%
plt.plot(a, torch.exp(norm.log_prob(a)))
plt.scatter(norm_sample,[0 for i in range(len(norm_sample))])

# %%
norm_sample = 2 * norm_sample + 5

# %%
norm_2 = dist.normal.Normal(torch.tensor([5.]), torch.tensor([4.]))
norm_sample_2 = norm_2.sample((1000,))
a = torch.tensor([i for i in torch.linspace(-5,15,100)])

plt.plot(a, torch.exp(norm_2.log_prob(a)))
plt.scatter(norm_sample, [0 for i in range(len(norm_sample))])
#plt.scatter(norm_sample_2,[0 for i in range(len(norm_sample_2))])

# %%
# prompt: plt.countourplot in 2 dim normal distribution using pytorch

import torch
import torch.distributions as dist
import matplotlib.pyplot as plt

# define parameters of the distribution
mu = torch.tensor([0., 0.])
sigma = torch.tensor([[1., 0.], [0., 1.]])

# create a multivariate normal distribution
mvn = dist.MultivariateNormal(mu, sigma)

# sample from the distribution
x = mvn.sample((1000,))

# plot the samples
plt.scatter(x[:, 0], x[:, 1])
plt.show()

# sample from the distribution
x = mvn.sample((1000,))
t_1 = 2*x+5

# plot the samples
plt.scatter(t_1[:, 0], t_1[:, 1])
plt.show()
torch.var(t_1)
norm = dist.normal.Normal(torch.tensor([0.]), torch.tensor([1.]))
norm_sample = norm.sample((1000,))
a = torch.tensor([i for i in torch.linspace(-5,5,100)])
plt.plot(a, torch.exp(norm.log_prob(a)))
plt.scatter(norm_sample,[0 for i in range(len(norm_sample))])
norm_sample = 2 * norm_sample + 5
norm_2 = dist.normal.Normal(torch.tensor([5.]), torch.tensor([4.]))
norm_sample_2 = norm_2.sample((1000,))
a = torch.tensor([i for i in torch.linspace(-5,15,100)])

plt.plot(a, torch.exp(norm_2.log_prob(a)))
plt.scatter(norm_sample, [0 for i in range(len(norm_sample))])
plt.scatter(norm_sample_2,[0 for i in range(len(norm_sample_2))])

# %%
# prompt: how to make contour plot in 2 dim normal distribution

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal

# Define the parameters of the distribution
mu = np.array([0, 0])
sigma = np.array([[1, 0], [0, 1]])

# Create a grid of points to evaluate the distribution at
x = np.linspace(-3, 3, 100)
y = np.linspace(-3, 3, 100)
X, Y = np.meshgrid(x, y)

# Evaluate the distribution at each point
Z = multivariate_normal.pdf(np.array([X, Y]).T, mean=mu, cov=sigma)

plt.figure(figsize=(4, 4))
# Plot the contour plot
plt.contour(X, Y, Z,50)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
plt.figure(figsize=(4, 4))
# Plot the contour plot
plt.contourf(X, Y, Z, 50)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 100)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('3D contour')

plt.show()
